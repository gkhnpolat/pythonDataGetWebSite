# %%
import requests #!pip install requests
from bs4 import BeautifulSoup #!pip install beautifulsoup4
import pandas as pd

sayac = 0
fiyat, marka, seri, model, yil, km, vites, yakit, kasa, renk, motorHacmi, motorGucu, cekis, yakitTuketimi, yakitDeposu, boyaDegisen, takas,kimden = [],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[]

yedek_url = ""
while sayac <= 37 : #37 sayısı sitedeki verinin sayfa sayısı
  sayac += 1
  def get_soup(TARGET_URL):
      page = requests.get(TARGET_URL)
      soup = BeautifulSoup(page.text, 'html.parser')
      return soup
    
  if sayac == 1: #pagination ile oluştutulan veileri sayfa sayfa çekme
    URL = 'https://www.arabam.com/ikinci-el/otomobil/audi-a3'
  else:
    URL = 'https://www.arabam.com/ikinci-el/otomobil/audi-a3?page=' + str(sayac)
  soup = get_soup(URL)
  

  
  soupDetay = ""
  bos = "-"
  for k in soup.find_all("a", href=True, attrs={'class':'link-overlay'}):
    url = "https://www.arabam.com" + str(k['href']) #ilanlara özel url 
    if yedek_url != url:
      yedek_url = url
      page = requests.get(url)
      soupDetay = BeautifulSoup(page.text, 'html.parser') # ilan detayı
      
      index = 0
      for j in soupDetay.find_all("div", attrs={'class':'property-value'}):
      
        verilen = len(soupDetay.find_all("div", attrs={'class':'property-value'}))
        kalandeger = 19 - verilen
        yeniden_düzenlenmis_metin = j.text.replace('\n', ' ').replace('  ', '').replace('\r ','')
      
        if index == 0:
          price = soupDetay.find_all("div", attrs={'class':'product-price'})
          priceDuzenleme = str(price).replace('\n', ' ').replace('  ', '').replace('\r ','').replace('[<div class="product-price">', '').replace('</div>]','')
          fiyat.append(priceDuzenleme)
          
          i = 1
          while i <= kalandeger:      
            if i == 1:
              kimden.append(bos)
            if i == 2:
              takas.append(bos)
            if i == 3:
              boyaDegisen.append(bos)
            if i == 4:
              yakitDeposu.append(bos)
            if i == 5:
              yakitTuketimi.append(bos)
            if  i == 6:
              cekis.append(bos)
            if i == 7:
              motorGucu.append(bos)
            i += 1    
     
        if index == 2:
          marka.append(yeniden_düzenlenmis_metin)
        
        if index == 3:
          seri.append(yeniden_düzenlenmis_metin)  
            
        if index == 4:
          model.append(yeniden_düzenlenmis_metin)
        
        if index == 5:
          yil.append(yeniden_düzenlenmis_metin)
              
        if index == 6:
          km.append(yeniden_düzenlenmis_metin)
        
        if index == 7:
          vites.append(yeniden_düzenlenmis_metin)
 
        if index == 8:
          yakit.append(yeniden_düzenlenmis_metin)
                     
        if index == 9:
          kasa.append(yeniden_düzenlenmis_metin)
        
        if index == 10:
          renk.append(yeniden_düzenlenmis_metin)
              
        if index == 11:
          motorHacmi.append(yeniden_düzenlenmis_metin)

        if index == 12:
          motorGucu.append(yeniden_düzenlenmis_metin)
              
        if index == 13:
          cekis.append(yeniden_düzenlenmis_metin)

        
        if index == 14:
          yakitTuketimi.append(yeniden_düzenlenmis_metin)
              
        if index == 15:
          yakitDeposu.append(yeniden_düzenlenmis_metin)
        
        if index == 16:
          boyaDegisen.append(yeniden_düzenlenmis_metin)
              
        if index == 17:      
          takas.append(yeniden_düzenlenmis_metin)
        
        if index == 18:
          kimden.append(yeniden_düzenlenmis_metin)
          index = 0
        
        
      
        index += 1
      
    else:
      yedek_url = ""
      
    
    

# print(len(fiyat), len(marka), len(seri), len(model), len(yil), len(km), len(vites), len(yakit), len(kasa), len(renk), len(motorHacmi), len(motorGucu), len(cekis), len(yakitTuketimi), len(yakitDeposu), len(boyaDegisen), len(takas),len(kimden))

pd.DataFrame({
    'fiyat': fiyat,
    'marka': marka,
    'seri': seri,
    'model': model,
    'yil': yil,
    'km': km,
    'vites': vites,
    'yakit': yakit,
    'kasa': kasa,
    'renk': renk,
    'motorHacmi': motorHacmi,
    'motorGucu': motorGucu,
    'cekis': cekis,
    'yakitTuketimi': yakitTuketimi,
    'yakitDeposu': yakitDeposu,
    'boyaDegisen': boyaDegisen,
    'takas': takas,
    'kimden': kimden
})
# Out:
#                                                  fiyat marka seri  \
# 0                                         1.250.000 TL  Audi   A3
# 1                                         1.198.950 TL  Audi   A3
# 2     <div class="price-discount" data-testid="desk...  Audi   A3
# 3                                         1.120.000 TL  Audi   A3
# 4                                         1.065.000 TL  Audi   A3
# ..                                                 ...   ...  ...
# 725                                       1.250.000 TL  Audi   A3
# 726                                         728.000 TL  Audi   A3
# 727                                         380.000 TL  Audi   A3
# 728                                         400.000 TL  Audi   A3
# 729                                       1.250.000 TL  Audi   A3
#
#                              model   yil          km          vites  \
# 0         A3 Sedan 30 TFSI Dynamic  2019   83.400 km  Yarı Otomatik
# 1       A3 Sedan 1.4 TFSI Ambition  2016   69.800 km  Yarı Otomatik
# 2    A3 Sportback 1.6 TDI Ambition  2013  191.000 km       Otomatik
# 3      A3 Sedan 1.6 TDI Sport Line  2017  181.000 km  Yarı Otomatik
# 4         A3 Sedan 1.6 TDI Dynamic  2017   16.200 km  Yarı Otomatik
# ..                             ...   ...         ...            ...
# 725      A3 Sedan 1.6 TDI Ambition  2014  120.000 km  Yarı Otomatik
# 726    A3 Sportback 1.6 Attraction  2010  145.000 km            Düz
# 727      A3 Sportback 1.6 Ambiente  1999  247.000 km       Otomatik
# 728    A3 Sportback 1.6 Attraction  2002  324.500 km            Düz
# 729   A3 Sportback 1.6 TDI Dynamic  2017   86.000 km       Otomatik
#
#             yakit         kasa            renk       motorHacmi     motorGucu  \
# 0          Benzin        Sedan  Mavi (metalik)           999 cc        116 hp
# 1          Benzin        Sedan           Beyaz          1395 cc        150 hp
# 2           Dizel  Hatchback/3         Kırmızı  1401 - 1600 cm3  101 - 125 HP
# 3           Dizel        Sedan           Siyah          1598 cc        110 hp
# 4           Dizel        Sedan           Beyaz          1598 cc        116 hp
# ..            ...          ...             ...              ...           ...
# 725         Dizel        Sedan         1598 cc           110 hp   Önden Çekiş
# 726  LPG & Benzin  Hatchback/3         1595 cc           102 hp   Önden Çekiş
# 727        Benzin  Hatchback/3            Mavi          1595 cc        101 hp
# 728  LPG & Benzin  Hatchback/5         1595 cc           101 hp   Önden Çekiş
# 729         Dizel  Hatchback/5           Beyaz     101 - 125 HP   Önden Çekiş
#
#                 cekis  yakitTuketimi       yakitDeposu            boyaDegisen  \
# 0         Önden Çekiş         4,4 lt             50 lt        Tamamı orjinal
# 1         Önden Çekiş         4,7 lt             50 lt        Tamamı orjinal
# 2                   -  Belirtilmemiş      Takasa Uygun              Galeriden
# 3         Önden Çekiş         3,7 lt             50 lt          Belirtilmemiş
# 4         Önden Çekiş         3,9 lt             50 lt   3 değişen, 1 boyalı
# ..                ...            ...               ...                    ...
# 725            3,9 lt          50 lt   Tamamı orjinal              Sahibinden
# 726            6,8 lt          55 lt     Belirtilmemiş             Sahibinden
# 727       Önden Çekiş         8,6 lt             55 lt          Belirtilmemiş
# 728            7,6 lt          55 lt         4 boyalı      Takasa Uygun Değil
# 729   Tamamı orjinal    Takasa Uygun        Sahibinden                      -
#
#                   takas      kimden
# 0          Takasa Uygun   Galeriden
# 1          Takasa Uygun   Galeriden
# 2                     -           -
# 3          Takasa Uygun   Galeriden
# 4    Takasa Uygun Değil   Galeriden
# ..                  ...         ...
# 725                   -           -
# 726                   -           -
# 727  Takasa Uygun Değil  Sahibinden
# 728          Sahibinden           -
# 729                   -           -
#
# [730 rows x 18 columns]
